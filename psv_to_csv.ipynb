# %%
import pandas as pd
keep_cols = ["DATE", "temperature", "wind_direction", "wind_speed", "wind_gust", "precipitation", "relative_humidity", "snow_depth", "pressure_3hr_change", "sky_cover_1", "sky_cover_2", "sky_cover_3", "sky_cover_baseht_1", "sky_cover_baseht_2", "sky_cover_baseht_3"]

df = pd.read_csv("/home/farid/NOAA/GHCNh_USW00013883_2025.psv", sep="|")

print(df[keep_cols].head())

df.to_csv("/home/farid/NOAA/output2025.csv", columns=keep_cols, index=False)
# Out:
#                   DATE  temperature  wind_direction  wind_speed  wind_gust  \
# 0  2025-01-01T00:00:00         17.8           210.0         3.6        NaN
# 1  2025-01-01T00:56:00         18.3           220.0         4.1        NaN
# 2  2025-01-01T01:56:00         17.2           280.0         9.8       13.9
# 3  2025-01-01T02:56:00         15.6           270.0         8.8       16.5
# 4  2025-01-01T03:00:00         15.6           270.0         8.8        NaN
#
#    precipitation  relative_humidity  snow_depth  pressure_3hr_change  \
# 0            NaN               68.0         NaN                  1.2
# 1            0.0               68.0         NaN                  NaN
# 2            0.0               52.0         NaN                  NaN
# 3            0.0               44.0         NaN                  2.9
# 4            NaN               44.0         NaN                  2.9
#
#   sky_cover_1 sky_cover_2 sky_cover_3  sky_cover_baseht_1  sky_cover_baseht_2  \
# ...
