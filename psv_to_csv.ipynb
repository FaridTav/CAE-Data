# %%
import pandas as pd
keep_cols = ["STATION"]

df = pd.read_csv("/home/farid/NOAA/GHCNh_USW00013883_2025.psv", sep="|")

print(df[keep_cols].head())

df.to_csv("/home/farid/NOAA/output.csv", columns=keep_cols, index=False)
# Out:
#        STATION
# 0  USW00013883
# 1  USW00013883
# 2  USW00013883
# 3  USW00013883
# 4  USW00013883
# /tmp/ipykernel_583639/2150190939.py:4: DtypeWarning: Columns (72,73,75,77,78,79,81,83,121,123,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/farid/NOAA/GHCNh_USW00013883_2025.psv", sep="|")
